# %% [markdown]
# - Re-writing the query
#     - Multi-query: rewrite the user question with multiple (different) phrasings, retrieve infor for each questions, return unique documents for all queries
#     - Decomposition: separate the question into several parts, answer each part sequentially or in parallel.
#     - Step-back: ??
#     - HyDE: ??

# %%
# Example of decomposition

from pydantic import BaseModel, Field
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage

# Define a pydantic model to enforce the output structure
class Questions(BaseModel):
    questions: list[str] = Field(
        description="A list of sub-questions related to the input query."
    )

# Create an instance of the model and enforce the output structure
model = ChatOllama(model="deepseek-r1:1.5b", temperature=0) 
structured_model = model.with_structured_output(Questions)

# Define the system prompt
system = """You are a helpful assistant that generates multiple sub-questions related to an input question. \n
The goal is to break down the input into a set of sub-problems / sub-questions that can be answers in isolation. \n"""

# Pass the question to the model
question = """What are the main components of an LLM-powered autonomous agent system?"""
questions = structured_model.invoke([SystemMessage(content=system)]+[HumanMessage(content=question)])
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[3], line 23
#      21 # Pass the question to the model
#      22 question = """What are the main components of an LLM-powered autonomous agent system?"""
# ---> 23 questions = structured_model.invoke([SystemMessage(content=system)]+[HumanMessage(content=question)])
#
# File ~/RAG/.ragvenv/lib/python3.10/site-packages/langchain_core/runnables/base.py:3014, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3012 context.run(_set_config_context, config)
#    3013 if i == 0:
# -> 3014     input = context.run(step.invoke, input, config, **kwargs)
#    3015 else:
#    3016     input = context.run(step.invoke, input, config)
#
# File ~/RAG/.ragvenv/lib/python3.10/site-packages/langchain_core/runnables/base.py:5352, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5346 def invoke(
#    5347     self,
#    5348     input: Input,
#    5349     config: Optional[RunnableConfig] = None,
#    5350     **kwargs: Optional[Any],
#    5351 ) -> Output:
# -> 5352     return self.bound.invoke(
#    5353         input,
#    5354         self._merge_configs(config),
#    5355         **{**self.kwargs, **kwargs},
#    5356     )
#
# File ~/RAG/.ragvenv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)
#     279     **kwargs: Any,
#     280 ) -> BaseMessage:
#     281     config = ensure_config(config)
#     282     return cast(
#     283         ChatGeneration,
# --> 284         self.generate_prompt(
#     285             [self._convert_input(input)],
#     286             stop=stop,
#     287             callbacks=config.get("callbacks"),
#     288             tags=config.get("tags"),
#     289             metadata=config.get("metadata"),
#     290             run_name=config.get("run_name"),
#     291             run_id=config.pop("run_id", None),
#     292             **kwargs,
#     293         ).generations[0][0],
#     294     ).message
#
# File ~/RAG/.ragvenv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:791, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     783 def generate_prompt(
#     784     self,
#     785     prompts: list[PromptValue],
#    (...)
#     788     **kwargs: Any,
#     789 ) -> LLMResult:
#     790     prompt_messages = [p.to_messages() for p in prompts]
# --> 791     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/RAG/.ragvenv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:638, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     635 for i, m in enumerate(messages):
#     636     try:
#     637         results.append(
# --> 638             self._generate_with_cache(
#     639                 m,
#     640                 stop=stop,
#     641                 run_manager=run_managers[i] if run_managers else None,
#     642                 **kwargs,
#     643             )
#     644         )
#     645     except BaseException as e:
#     646         if run_managers:
#
# File ~/RAG/.ragvenv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:856, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     854 else:
#     855     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 856         result = self._generate(
#     857             messages, stop=stop, run_manager=run_manager, **kwargs
#     858         )
#     859     else:
#     860         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/RAG/.ragvenv/lib/python3.10/site-packages/langchain_ollama/chat_models.py:701, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     694 def _generate(
#     695     self,
#     696     messages: List[BaseMessage],
#    (...)
#     699     **kwargs: Any,
#     700 ) -> ChatResult:
# --> 701     final_chunk = self._chat_stream_with_aggregation(
#     702         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     703     )
#     704     generation_info = final_chunk.generation_info
#     705     chat_generation = ChatGeneration(
#     706         message=AIMessage(
#     707             content=final_chunk.text,
#    (...)
#     711         generation_info=generation_info,
#     712     )
#
# File ~/RAG/.ragvenv/lib/python3.10/site-packages/langchain_ollama/chat_models.py:602, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     593 def _chat_stream_with_aggregation(
#     594     self,
#     595     messages: List[BaseMessage],
#    (...)
#     599     **kwargs: Any,
#     600 ) -> ChatGenerationChunk:
#     601     final_chunk = None
# --> 602     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     603         if not isinstance(stream_resp, str):
#     604             chunk = ChatGenerationChunk(
#     605                 message=AIMessageChunk(
#     606                     content=(
#    (...)
#     619                 ),
#     620             )
#
# File ~/RAG/.ragvenv/lib/python3.10/site-packages/langchain_ollama/chat_models.py:589, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     586 chat_params = self._chat_params(messages, stop, **kwargs)
#     588 if chat_params["stream"]:
# --> 589     yield from self._client.chat(**chat_params)
#     590 else:
#     591     yield self._client.chat(**chat_params)
#
# File ~/RAG/.ragvenv/lib/python3.10/site-packages/ollama/_client.py:167, in Client._request.<locals>.inner()
#     165 except httpx.HTTPStatusError as e:
#     166   e.response.read()
# --> 167   raise ResponseError(e.response.text, e.response.status_code) from None
#     169 for line in r.iter_lines():
#     170   part = json.loads(line)
#
# ResponseError: registry.ollama.ai/library/deepseek-r1:1.5b does not support tools
